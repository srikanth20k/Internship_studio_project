# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [importing the Requirements](#toc1_1_1_)
#         - [Load the dataset](#toc1_1_1_1_1_)
#         - [Dataset Overview](#toc1_1_1_1_2_)
#     - [Exploratory Data Analysis   : - EDA](#toc1_1_2_)
#       - [Columns  in the dataset](#toc1_1_2_1_)
#       - [Dealing with null values](#toc1_1_2_2_)
#       - [Dealing with column data types](#toc1_1_2_3_)
#       - [Dealing with Duplicates](#toc1_1_2_4_)
#       - [Descriptive Statistics](#toc1_1_2_4_1_)
#       - [Univarient Analysis](#toc1_1_2_5_)
#         - [🧮 Math Score Distribution](#toc1_1_2_6_)
#         - [📖 Reading Score Distribution](#toc1_1_2_7_)
#         - [✍🏻 Writing Score Distribution](#toc1_1_3_)
#       - [Bivariate Analysis](#toc1_1_4_)
#       - [Correlation Between Exam Scores](#toc1_1_5_)
#       - [Multivarient Analysis](#toc1_1_6_)
#     - [Selecting the Model from differnt models](#toc1_1_6_1_)
#     - [Preprocessing](#toc1_1_6_1_1_)
#         - [Label encoding](#toc1_1_6_2_)
#         - [Separating the Train amd Test for the data](#toc1_1_6_3_)
#         - [Models buliding with different models](#toc1_1_6_4_)
#         - [Choosing the best model](#toc1_1_6_5_)
#     - [Model Buildig with best model](#toc1_1_7_)
#       - [Model score](#toc1_1_7_1_)
#       - [Graph for Actual and Predicated](#toc1_1_7_2_)
#       - [Differance betwwen the actual and predicted](#toc1_1_7_3_)
#     - [Conclusion](#toc1_1_8_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[importing the Requirements](#toc0_)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
sns.set(style="whitegrid")
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##### <a id='toc1_1_1_1_1_'></a>[Load the dataset](#toc0_)

# %%
df = pd.read_csv(r"C:\Users\SRIKANTH ADIPIREDDY\Desktop\Intership_studio\student_performance\StudentsPerformance_3_lyst1729690388778 (1).csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ##### <a id='toc1_1_1_1_2_'></a>[Dataset Overview](#toc0_)

# %%
print(f"No of rows : {df.shape[0]} and no of columns : {df.shape[1]} ")
print(df.info())
# Out:
# No of rows : 1000 and no of columns : 8
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None

# %% [markdown]
# * There no missing values in the dataset

# %% [markdown]
# ### <a id='toc1_1_2_'></a>[Exploratory Data Analysis   : - EDA](#toc0_)

# %% [markdown]
# #### <a id='toc1_1_2_1_'></a>[Columns  in the dataset](#toc0_)

# %%
for i in df.columns:
    print(i)
# Out:
# gender
# race/ethnicity
# parental level of education
# lunch
# test preparation course
# math score
# reading score
# writing score

# %% [markdown]
# #### <a id='toc1_1_2_2_'></a>[Dealing with null values](#toc0_)

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# average score                  0
# dtype: int64

# %% [markdown]
# #### <a id='toc1_1_2_3_'></a>[Dealing with column data types](#toc0_)

# %%
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                       int64
# reading score                    int64
# writing score                    int64
# average score                  float64
# dtype: object

# %% [markdown]
# #### <a id='toc1_1_2_4_'></a>[Dealing with Duplicates](#toc0_)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### <a id='toc1_1_2_4_1_'></a>[Descriptive Statistics](#toc0_)

# %%
print("\n  Descriptive Statistics")
print(df.describe())
# Out:
#   Descriptive Statistics
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# #### <a id='toc1_1_2_5_'></a>[Univarient Analysis](#toc0_)
# * ⚧️ Gender Distribution

# %%
fig = px.bar(data_frame=df, x='gender',
             height=500, width=800, color='gender', template='plotly_dark',
             color_discrete_sequence=px.colors.qualitative.Plotly
             )
fig.update_layout(title_text="No of Females and Males Students",
                  title_x=0.5, title_y=0.95)

# %%
fig = px.bar(df, x='race/ethnicity', 
             height=500, width=800, color='race/ethnicity', 
             color_discrete_sequence=px.colors.qualitative.Plotly,
             template='plotly_dark',title=" Student Race/Ethnicity Distribution")
fig.update_layout(title_x=0.5, title_y=0.95)
fig.show()

# %% [markdown]
# * 💡 Group C has the highest number of students, followed by Group D and B. This distribution can impact the fairness of aggregated score insights across groups.

# %% [markdown]
# #### <a id='toc1_1_2_6_'></a>[🧮 Math Score Distribution](#toc0_)

# %%
plt.figure(figsize=(8,5))
sns.set_theme(style='whitegrid')

sns.histplot(df['math score'], kde=True, color='#4285F4', bins=20)

plt.title('Distribution of Math Scores', fontsize=14, fontweight='bold')
plt.xlabel('Math Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# * 💡The distribution of math scores appears slightly left-skewed, with a concentration between 60 and 80. A notable number of students also scored below 50, suggesting performance gaps among certain subgroups.

# %% [markdown]
# #### <a id='toc1_1_2_7_'></a>[📖 Reading Score Distribution](#toc0_)

# %%
plt.figure(figsize=(8,5))
sns.set_theme(style='whitegrid')

sns.histplot(df['reading score'], kde=True, color='#EA4335', bins=20)

plt.title('Distribution of Reading Scores', fontsize=14, fontweight='bold')
plt.xlabel('Reading Score', fontsize=12)
plt.ylabel('Frequencey', fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# * 💡The reading scores show a more symmetric distribution compared to math scores. A high concentration lies between 70 and 90, suggesting generally better reading performance.

# %% [markdown]
# ### <a id='toc1_1_3_'></a>[✍🏻 Writing Score Distribution](#toc0_)

# %%
plt.figure(figsize=(8,5))
sns.set_theme(style='whitegrid')

sns.histplot(df['writing score'], kde=True, color='#FBBC05', bins=20)

plt.title('Distibution of Writing Scores', fontsize=14, fontweight='bold')
plt.xlabel('Writing Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <a id='toc1_1_4_'></a>[Bivariate Analysis](#toc0_)

# %%
sns.set_theme(style='whitegrid')  # Set consistent theme

# 1. Math Score by Parental Education
plt.figure(figsize=(12, 6))
sns.boxplot(x='parental level of education', y='math score', data=df, color='#34A853')  # Google green
plt.title('Math Score vs Parental Level of Education', fontsize=14, fontweight='bold')
plt.xlabel('Parental Education Level', fontsize=12)
plt.ylabel('Math Score', fontsize=12)
plt.xticks(rotation=45, fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.show()

# 2. Average Score by Gender
df['average score'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)

plt.figure(figsize=(6, 4))
sns.boxplot(x='gender', y='average score', data=df, color='#4285F4')  # Google blue
plt.title('Average Exam Score by Gender', fontsize=14, fontweight='bold')
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Average Score', fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.show()

# 3. Lunch Type vs Average Score
plt.figure(figsize=(6, 4))
sns.boxplot(x='lunch', y='average score', data=df, color='#EA4335')  # Google red
plt.title('Lunch Type vs Average Exam Score', fontsize=14, fontweight='bold')
plt.xlabel('Lunch Type', fontsize=12)
plt.ylabel('Average Score', fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.show()

# 4. Test Preparation Course vs Average Score
plt.figure(figsize=(6, 4))
sns.boxplot(x='test preparation course', y='average score', data=df, color='#FBBC05')  # Google yellow
plt.title('Test Preparation vs Average Exam Score', fontsize=14, fontweight='bold')
plt.xlabel('Test Preparation Course', fontsize=12)
plt.ylabel('Average Score', fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <a id='toc1_1_5_'></a>[Correlation Between Exam Scores](#toc0_)

# %%
plt.figure(figsize=(6, 5))
sns.set_theme(style='whitegrid')

corr_matrix = df[['math score', 'reading score', 'writing score', 'average score']].corr()

sns.heatmap(corr_matrix, annot=True, cmap='YlGnBu', linewidths=0.5, linecolor='white', square=True, cbar_kws={'shrink': 0.75})

plt.title('Correlation Between Exam Scores', fontsize=14, fontweight='bold')
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <a id='toc1_1_6_'></a>[Multivarient Analysis](#toc0_)

# %%
sns.pairplot(df[['math score', 'reading score', 'writing score','average score']], diag_kind='kde', markers='o', palette='Set2')
plt.suptitle('Pairplot of Exam Scores', y=1.02, fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 1.02, 'Pairplot of Exam Scores')

# %% [markdown]
# #### <a id='toc1_1_6_1_'></a>[Selecting the Model from differnt models](#toc0_)

# %%
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'average score'],
#       dtype='object')

# %% [markdown]
# ##### <a id='toc1_1_6_1_1_'></a>[preprocessing](#toc0_)

# %%
x = df.drop(
    columns='math score',axis=1
)
y = df['math score']

# %%
x.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  reading score  writing score  average score
# 0                    none             72             74      72.666667
# 1               completed             90             88      82.333333
# 2                    none             95             93      92.666667
# 3                    none             57             44      49.333333
# 4                    none             78             75      76.333333

# %%
y.head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math score, dtype: int64

# %%
for i in df.select_dtypes(include=['object']).columns:
    print(f"{i} : " ,df[i].unique())
# Out:
# gender :  ['female' 'male']
# race/ethnicity :  ['group B' 'group C' 'group A' 'group D' 'group E']
# parental level of education :  ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# lunch :  ['standard' 'free/reduced']
# test preparation course :  ['none' 'completed']

# %%
num_col = x.select_dtypes(include=['int64','float64']).columns
cat_col = x.select_dtypes(include=['object']).columns

# %% [markdown]
# #### <a id='toc1_1_6_2_'></a>[Label encoding](#toc0_)

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer

num_trans = StandardScaler()
oh_trans = OneHotEncoder()

preprocessor = ColumnTransformer(
    [
        ("OneHotEncoder",oh_trans,cat_col),
        ("StandardScaler",num_trans,num_col)
    ]
)

# %%
x = preprocessor.fit_transform(x)

# %%
x.shape
# Out:
# (1000, 20)

# %% [markdown]
# #### <a id='toc1_1_6_3_'></a>[Separating the Train amd Test for the data](#toc0_)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (800, 20)

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2 = r2_score(true, predicted)
    return mae,mse,rmse,r2

# %% [markdown]
# #### <a id='toc1_1_6_4_'></a>[Models buliding with different models](#toc0_)

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Lasso Regression": Lasso(),
    "Ridge Regression": Ridge(),
    "KNN": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor()
}

models_list =[]
r2_list = []


for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train,y_train)
    
    # Predicting the test set results
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)
    
    # Evaluating the model
    model_train_mae ,model_train_mse,model_train_rmse, model_train_r2 = evaluate_model(y_train,y_train_pred)
    
    model_test_mae , model_test_mse,model_test_rmse, model_test_r2 = evaluate_model(y_test,y_test_pred)
    
    print(list(models.keys())[i])
    models_list.append(list(models.keys())[i])
    
    print('model performance on train data')
    print("-> Root Mean Squared Error : {:.4f} ".format(model_train_rmse))
    print("-> Mean Absolute Error  : {:.4f} ".format(model_train_mae))
    print("-> R2 Score  : {:.4f} ".format(model_train_r2))
    
    print("-----------------------------------")
    
    print("model performance on test data")
    print("-> Root Mean Squared Error: {:.4f} ".format(model_test_rmse))
    print("-> Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("-> R2 Score: {:.4f}".format(model_test_r2))
    r2_list.append(model_test_r2)
    
    print("="*35)
    print("\n")
# Out:
# Linear Regression
# model performance on train data
# -> Root Mean Squared Error : 0.0000
# -> Mean Absolute Error  : 0.0000
# -> R2 Score  : 1.0000
# -----------------------------------
# model performance on test data
# -> Root Mean Squared Error: 0.0000
# -> Mean Absolute Error: 0.0000
# -> R2 Score: 1.0000
# ...
#
#
# Lasso Regression
# model performance on train data
# -> Root Mean Squared Error : 4.7381
# -> Mean Absolute Error  : 3.7439
# -> R2 Score  : 0.9004
# -----------------------------------
# model performance on test data
# -> Root Mean Squared Error: 4.7171
# -> Mean Absolute Error: 3.7579
# -> R2 Score: 0.9086
# ...
#
#
# Ridge Regression
# model performance on train data
# -> Root Mean Squared Error : 0.5171
# -> Mean Absolute Error  : 0.4147
# -> R2 Score  : 0.9988
# -----------------------------------
# model performance on test data
# -> Root Mean Squared Error: 0.5229
# -> Mean Absolute Error: 0.4086
# -> R2 Score: 0.9989
# ...
#
#
# KNN
# model performance on train data
# ...

# %% [markdown]
# #### <a id='toc1_1_6_5_'></a>[Choosing the best model](#toc0_)

# %%
pd.DataFrame({'Model':models_list,'R2 Score':r2_list}).sort_values(by='R2 Score',ascending=False)
# Out:
#                Model  R2 Score
# 0  Linear Regression  1.000000
# 2   Ridge Regression  0.998877
# 5      Random Forest  0.962123
# 4      Decision Tree  0.931269
# 1   Lasso Regression  0.908560
# 3                KNN  0.856486

# %% [markdown]
# ### <a id='toc1_1_7_'></a>[Model Buildig with best model](#toc0_)
# * Linear Regression

# %%
lr = LinearRegression(fit_intercept=True)
lr = lr.fit(x_train,y_train)
y_test_pred = lr.predict(x_test)
score = r2_score(y_test,y_train_pred)*100
print(f"R2 score of Linear Regression model is : {score:.2f} %")
# Out:
# R2 score of Linear Regression model is : 100.00 %

# %% [markdown]
# #### <a id='toc1_1_7_1_'></a>[Model score](#toc0_)

# %%
lr.fit(x_train,y_train)
print(lr.score(x_train,y_train))
print(lr.score(x_test,y_test))
# Out:
# 1.0
# 1.0

# %% [markdown]
# #### <a id='toc1_1_7_2_'></a>[Graph for Actual and Predicated](#toc0_)

# %%
plt.scatter(y_test,y_test_pred)
plt.xlabel('Actual Values',fontsize=12)
plt.ylabel('Predicted Values',fontsize=12)
plt.title('Actual vs Predicted Values',fontsize=14,fontweight='bold')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, color='red')

# %%
sns.regplot(x=y_test,
            y=y_test_pred,
            ci=None,
            color='red')
plt.xlabel('Actual Values',fontsize=12)
plt.ylabel('Predicted Values',fontsize=12)
plt.title('Actual vs Predicted Values',fontsize=14,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted Values')

# %% [markdown]
# #### <a id='toc1_1_7_3_'></a>[Differance betwwen the actual and predicted](#toc0_)

# %%
pred = pd.DataFrame({'Actual':y_test,'Predicted':y_test_pred,'Differance': round(y_test-y_test_pred,2)})

# %%
pred
# Out:
#      Actual  Predicted  Differance
# 521      91      82.62        8.38
# 737      53      54.67       -1.67
# 740      80      78.13        1.87
# 660      74      74.13       -0.13
# 411      84      84.04       -0.04
# ..      ...        ...         ...
# 408      52      51.77        0.23
# 332      62      61.98        0.02
# 208      74      71.17        2.83
# 613      65      65.70       -0.70
# 78       61      61.39       -0.39
#
# [200 rows x 3 columns]

# %% [markdown]
# ### <a id='toc1_1_8_'></a>[Conclusion](#toc0_)

# %% [markdown]
# ##### 📝 Key Insights¶
# Here are the most valuable takeaways from our analysis:
#
# * 👩‍🏫 Gender Trends: Female students performed better in reading and writing scores on average.
# * 📚 Test Preparation Matters: Completing the test preparation course significantly boosts overall academic performance.
# * 🍱 Lunch Status Impact: Students who receive standard lunch tend to score higher than those with free/reduced lunch, hinting at economic factors.
# * 🎓 Parental Education Effect: Students with parents who have higher educational attainment tend to perform better, especially in math.
# * 🔗 Score Correlation: There's a strong positive correlation among math, reading, and writing scores — students good at one subject often excel in others.
#
#
# This exploratory data analysis provided meaningful insights into how demographic and support-related factors influence student performance.
#
# We observed clear patterns in how preparation, parental background, and economic context correlate with academic results. These findings could inform educational interventions, resource allocation, and student support programs.
